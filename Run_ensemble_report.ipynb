# %%
from filewise_ensemble import file_wise_ensemble

# %%
file_wise_ensemble()
# Out:
# *********** Datasets/autoencoder_dataset ***********
# Prediction scores of each tree corresponding to each point
# {'Fp1': 1.0, 'Fp2': 0.4185185185185185, 'F3': 0.4444444444444444, 'F4': 0.3925925925925926, 'C3': 0.4648148148148148, 'C4': 0.45925925925925926, 'P3': 0.5351851851851852, 'P4': 0.48148148148148145, 'O1': 0.4981481481481482, 'O2': 0.45925925925925926, 'A1': 0.4351851851851852, 'A2': 0.4074074074074074, 'F7': 0.39814814814814814, 'F8': 0.4388888888888889, 'T3': 0.39444444444444443, 'T4': 0.35, 'T5': 0.5277777777777778, 'T6': 0.4074074074074074, 'Fz': 0.38333333333333336, 'Cz': 0.4444444444444444, 'Pz': 0.4388888888888889}
# maximum accuracy of data point: Fp1
#
#  Final classification result after voting
#
#               precision    recall  f1-score   support
#
#            1       0.67      0.75      0.71       171
#            2       0.80      0.71      0.75       214
#            3       0.77      0.81      0.79       155
#
# ...

# %%
list_area = ['F3,''F4','C3','C4','Cz']
file_wise_ensemble(only_motor=True, list_area = list_area)
# Out:
# *********** Datasets/autoencoder_dataset ***********
# Prediction scores of each tree corresponding to each point
# {'Fp1': 0.9981481481481481, 'Fp2': 0.4148148148148148, 'F3': 0.4166666666666667, 'F4': 0.362962962962963, 'C3': 0.4759259259259259, 'C4': 0.43703703703703706, 'P3': 0.5092592592592593, 'P4': 0.48333333333333334, 'O1': 0.5074074074074074, 'O2': 0.42592592592592593, 'A1': 0.362962962962963, 'A2': 0.4185185185185185, 'F7': 0.3888888888888889, 'F8': 0.46296296296296297, 'T3': 0.4203703703703704, 'T4': 0.3888888888888889, 'T5': 0.5185185185185185, 'T6': 0.42407407407407405, 'Fz': 0.40925925925925927, 'Cz': 0.4462962962962963, 'Pz': 0.4351851851851852}
# maximum accuracy of data point: Fp1
#
#  Final classification result after voting
#
#               precision    recall  f1-score   support
#
#            1       0.41      0.41      0.41       160
#            2       0.53      0.53      0.53       204
#            3       0.51      0.52      0.52       176
#
# ...

# %%
list_area = ['C3','C4','T4','Cz','P3','P4','O1','A1','T3']
file_wise_ensemble(only_motor=True, list_area = list_area)
# Out:
# *********** Datasets/autoencoder_dataset ***********
# Prediction scores of each tree corresponding to each point
# {'Fp1': 1.0, 'Fp2': 0.3611111111111111, 'F3': 0.4148148148148148, 'F4': 0.4166666666666667, 'C3': 0.40185185185185185, 'C4': 0.4462962962962963, 'P3': 0.512962962962963, 'P4': 0.4666666666666667, 'O1': 0.5018518518518519, 'O2': 0.4722222222222222, 'A1': 0.4185185185185185, 'A2': 0.3925925925925926, 'F7': 0.3925925925925926, 'F8': 0.43333333333333335, 'T3': 0.38333333333333336, 'T4': 0.37962962962962965, 'T5': 0.4981481481481482, 'T6': 0.42777777777777776, 'Fz': 0.40370370370370373, 'Cz': 0.42407407407407405, 'Pz': 0.3962962962962963}
# maximum accuracy of data point: Fp1
#
#  Final classification result after voting
#
#               precision    recall  f1-score   support
#
#            1       0.40      0.52      0.45       141
#            2       0.67      0.51      0.58       236
#            3       0.52      0.56      0.54       163
#
# ...
